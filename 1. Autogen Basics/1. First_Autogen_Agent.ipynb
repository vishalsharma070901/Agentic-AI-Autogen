# %% [markdown]
# # Our First Autogen Agent

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # My First AutoGen Agent (v0.4)
# In this notebook, we’ll build a simple agent using AutoGen v0.4 and OpenAI’s GPT-4. We’ll ask it a fun question and see how it responds. This is the latest version, so you’re learning the cutting-edge way to create AI agents!

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_core.models import UserMessage
from autogen_ext.models.openai import OpenAIChatCompletionClient
from dotenv import load_dotenv
import os
import dotenv

load_dotenv()

# api_key = os.getenv('OPENAI_API_KEY')
# Out:
# True

# %% [markdown]
# ## Connecting to the Model
# We use `OpenAIChatCompletionClient` to link our agent to lama-3.3-70b-versatile. In v0.4, this replaces the older `llm_config` approach.

# %%
# model_client = OpenAIChatCompletionClient(model='gpt-4',api_key=api_key)


groq_model_client = OpenAIChatCompletionClient(
    model="llama-3.3-70b-versatile",
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1",
    model_info={
        "family": "llama",
        "vision": False,
        "function_calling": True,
        "json_output": True,
        "structured_output": True,
    },
)

response = await groq_model_client.create(
    [
        UserMessage(
            content="explain about reactjs in 100 words",
            source="user"
        )
    ]
)


print(response.content)

# await groq_model_client.close()
# Out:
# ReactJS is a JavaScript library for building user interfaces. It allows developers to create reusable UI components and manage state changes efficiently. React uses a virtual DOM to optimize rendering and updates, making it fast and scalable. It's ideal for building complex, data-driven web applications, and is often used with other libraries like Redux and React Router. React's declarative programming style and modular design make it a popular choice for web development, especially for large-scale and complex applications. It's maintained by Facebook and has a large community of developers. It simplifies the development process.

# %% [markdown]
# ## Building the Agent
# The `AssistantAgent` is a conversational AI that can respond to tasks. We’ll give it a name and connect it to our model.

# %%
assistant = AssistantAgent(name = 'my_assistant',model_client=groq_model_client)

# %% [markdown]
# ## Asking the Agent a Question
# We’ll use the `run` method—a simple way in v0.4 to get a response. Watch this!

# %%
result = await assistant.run(task = "Tell me a fun fact about space.")

print(result)
# Out:
# messages=[TextMessage(source='user', models_usage=None, metadata={}, content='Tell me a fun fact about space.', type='TextMessage'), TextMessage(source='my_assistant', models_usage=RequestUsage(prompt_tokens=67, completion_tokens=95), metadata={}, content="A fun fact about space is that there is a giant storm on Jupiter that has been raging for at least 150 years, known as the Great Red Spot. It's so large that three Earths could fit inside it. The storm is a persistent anticyclonic storm, meaning that it's a high-pressure region with clockwise rotation, and its distinctive red color is thought to be due to the presence of sulfur and phosphorus compounds in the clouds.\n\nTERMINATE", type='TextMessage')] stop_reason=None

# %%
print(result.messages[-1].content)
# Out:
# A fun fact about space is that there is a giant storm on Jupiter that has been raging for at least 150 years, known as the Great Red Spot. It's so large that three Earths could fit inside it. The storm is a persistent anticyclonic storm, meaning that it's a high-pressure region with clockwise rotation, and its distinctive red color is thought to be due to the presence of sulfur and phosphorus compounds in the clouds.
#
# TERMINATE

# %%
result = await assistant.run(task = "Tell me what is 5+25")
print(result.messages[-1].content)
# Out:
# 5 + 25 = 30.
#
# TERMINATE
